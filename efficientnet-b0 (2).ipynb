# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_df_rectified.csv
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387936.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2334070.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2409937.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2376521.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2363057.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2317630.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2406500.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2343506.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2395804.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2355594.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2403321.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2384825.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2398610.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2335963.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2407631.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2366495.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2341799.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2360671.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2402337.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2376294.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2408191.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2325095.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2414377.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354075.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354848.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2336468.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2322605.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2417435.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2414564.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2398702.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2344952.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2341823.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2373214.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2366029.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2375570.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2360114.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2386558.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2366070.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2385643.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2356073.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2405400.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2361287.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412964.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2346175.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2408642.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2356553.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2367237.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2336606.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2404711.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2353247.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/1592672.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2358396.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2399058.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2368796.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2375805.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2386433.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2348383.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2408982.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2376975.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2360869.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2381551.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2369760.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354440.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387146.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2397405.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2397275.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2333894.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2413356.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2384755.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2326075.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2401422.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2340450.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2357499.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2391203.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/764.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2358008.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2335674.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2363317.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2404760.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2330197.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2393621.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2316734.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2327729.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2319832.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2323295.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2401075.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2343078.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2383298.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2347312.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2406761.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387836.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2358312.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2364883.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2318973.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2353849.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2379791.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2318428.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2352258.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354663.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2345047.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2358940.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2369180.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2367384.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2413247.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2318555.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2395395.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412060.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2378127.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2411779.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2359523.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2369855.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2399143.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2400652.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2370771.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2397095.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2403683.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2370036.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2400994.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2338932.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387305.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2391639.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2376866.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2365245.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2362928.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2385543.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2417402.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2373196.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2331127.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2403633.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2363436.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2334130.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2403795.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2406574.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2372124.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2398640.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2366121.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2364315.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2341106.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2372008.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2357384.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2352059.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2358334.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2394278.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350121.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2364067.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2407315.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387815.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2402108.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2388592.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2417536.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2384690.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412921.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2414626.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2394250.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2394213.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2339440.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354134.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2404557.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2357716.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354627.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2341123.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2348177.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2361335.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350824.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2373796.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2348913.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2344141.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2382293.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2351072.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2407377.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2402792.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2355715.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2377207.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2371182.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2346972.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2345655.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2386125.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2337797.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2366682.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2382172.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2384897.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2401541.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2414668.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2323101.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2396309.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2394560.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2378834.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2372253.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2395206.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2369900.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2384746.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2413530.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2374279.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2317987.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2372145.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2330828.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2353974.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2402489.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2395809.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2408426.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2413536.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2356507.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2401305.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2415308.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354794.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2382276.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2382857.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2362203.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2403301.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2341442.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2395301.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2374257.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2353560.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2399932.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2357764.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2404824.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2363169.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2400256.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350694.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2349139.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2381684.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2395371.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2379300.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2391668.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2415738.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2375027.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2365718.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2355511.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2322967.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2349293.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2361312.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387239.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2326179.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2410767.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2358711.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2322428.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2413085.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2325989.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2368969.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2327911.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2334371.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2316411.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2408688.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2353845.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2328247.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2400354.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2344002.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2355307.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2375908.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350690.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2384133.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2370172.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2372837.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2374389.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2351576.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2370296.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2375529.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2408121.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2326419.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2398844.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2378824.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2400279.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2358788.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2335640.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2389756.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2416829.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2390981.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2322202.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2352006.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2359309.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2346520.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2373177.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2403105.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2355746.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2335084.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2400376.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2373893.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2340703.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2361871.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2370787.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2360465.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354013.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2349595.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2366451.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354310.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350985.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354840.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2373925.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387321.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2390948.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2409862.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2405082.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2364749.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354891.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2316314.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2384602.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2400766.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2326483.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2391545.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2392447.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2369018.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2351828.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2394027.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2364373.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2356835.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2389615.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2360572.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2406584.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2355513.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2389619.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2371023.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2338279.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2403010.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2361019.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2398628.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2317035.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2391730.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2324417.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2401910.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2345658.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2392154.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354987.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2413516.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2376166.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2398255.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2382916.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2365436.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2329646.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2359238.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2394152.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2353350.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2335662.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2405360.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412809.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2373735.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2405805.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2344308.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2362937.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2372903.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2339249.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2393255.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387669.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2400493.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2413616.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2366857.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350986.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2343703.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2381863.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2356399.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2322814.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2316338.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2365928.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2381571.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2343554.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2324578.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350481.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2330589.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412741.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2379551.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2399588.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2396047.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2380855.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2373460.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2358834.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2369882.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2326380.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2392917.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2334697.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2365263.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2366446.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2411458.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2385871.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2385253.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2341494.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2352092.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2352573.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2330143.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2355371.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2333157.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2382895.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2408794.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2345640.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2318780.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387473.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2335604.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412573.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2385652.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2333707.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2385598.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2399724.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2377222.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2413906.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2405319.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2375167.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2357391.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2316407.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2410547.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2327610.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2410116.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2404844.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2319650.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2367472.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2368073.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2408894.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/239.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2349459.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2336012.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2388808.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2348928.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2343649.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2416633.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2414961.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2337182.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2317122.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2376439.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2318166.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2352947.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2346603.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2411571.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2384184.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2416605.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2346288.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2349347.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387957.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2391424.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2318810.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2358907.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2393967.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2368881.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2323025.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2347235.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412884.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2383188.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2390032.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2363721.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2335446.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2407726.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2326348.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2370809.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2359096.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2341737.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2406038.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2404198.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2326485.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2363094.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2352626.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2368753.jpg
# ...
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2391334.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2349382.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2344038.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2386990.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/713210.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2378589.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2360380.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350877.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2361025.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2378622.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2371995.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2340936.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2379473.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2316260.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2322431.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2376186.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2365947.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2344641.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412609.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2416836.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2385317.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2378280.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2318286.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2376491.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354003.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2373922.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387897.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2368929.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354797.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2417038.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2364582.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2372932.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412980.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2399436.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/364.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2399281.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2324753.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387021.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/498035.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2351290.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2405057.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2406161.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350331.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2414449.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2355739.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2365141.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2377072.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2390515.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2352226.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412068.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2407586.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2401543.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412148.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2345107.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2360315.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2410788.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2325731.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2395995.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2357941.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2405695.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2336456.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2354288.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2381006.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2355648.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/1159875.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2370502.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2339208.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2389507.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2374778.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2411293.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2387906.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2395496.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2411703.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2348594.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2355770.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2412877.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2379994.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2358394.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2365700.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2335695.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2402584.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2403611.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2407513.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2358880.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2336155.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/1979.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2349983.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2331990.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2344543.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2411447.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2362386.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2348403.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2395576.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2361695.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2319404.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2367932.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2362911.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2362935.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2337008.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2351006.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2401487.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350886.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2382974.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2360098.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2393334.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2404369.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2372270.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2365462.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2339689.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2353627.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2341218.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2376660.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2356052.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350476.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2341382.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2347304.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2396951.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2342177.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2356482.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2349432.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2333541.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2350752.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2386935.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2405924.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2335993.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2357001.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2414555.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2366454.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2394798.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2321534.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2411459.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2389436.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2361411.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2381918.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2369897.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2408494.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2390384.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2388772.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2344255.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2353466.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2401442.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2322979.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2335664.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2413783.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2415587.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2342817.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2361288.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2342471.jpg
# /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images/2365614.jpg

# %%
import os
import pandas as pd
import requests
from PIL import Image
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu

dataset_path = '/kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_df_rectified.csv'
image_folder_path = '/kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images'

dataset = pd.read_csv(dataset_path)
dataset = dataset.sample(2000, random_state=42).reset_index(drop=True)
print(f"Reduced dataset size: {len(dataset)} rows")
print(dataset.head())

image_files = [f for f in os.listdir(image_folder_path) if f.endswith(('.jpg', '.jpeg', '.png'))]
print(f"Found {len(image_files)} images in {image_folder_path}")
print("Sample images:", image_files[:5])

new_image_folder = '/kaggle/working/downloaded_images'
os.makedirs(new_image_folder, exist_ok=True)
# Out:
# Reduced dataset size: 2000 rows
#    Image_name                                          Paragraph  train  \
# 0     2353881  This photograph is of buildings on a crowded s...   True
# 1     2373958  The bags are on the conveyor belt at the airpo...  False
# 2     2356551  Two giraffes and an antelope are in a large di...   True
# 3     2318965  A man walks his dog across a rain soaked stree...   True
# 4     2373308  Some zebras stand in a field. Two of them are ...   True
#
#     test                                                url    val
# 0  False  https://cs.stanford.edu/people/rak248/VG_100K/...  False
# 1   True  https://cs.stanford.edu/people/rak248/VG_100K/...  False
# 2  False  https://cs.stanford.edu/people/rak248/VG_100K/...  False
# 3  False  https://cs.stanford.edu/people/rak248/VG_100K/...  False
# 4  False  https://cs.stanford.edu/people/rak248/VG_100K/...  False
# Found 19551 images in /kaggle/input/stanford-image-paragraph-captioning-dataset/stanford_img/content/stanford_images
# Sample images: ['2387936.jpg', '2334070.jpg', '2409937.jpg', '2376521.jpg', '2363057.jpg']

# %%
def download_image(url, filename, output_folder):
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            image_path = os.path.join(output_folder, filename)
            with open(image_path, 'wb') as f:
                f.write(response.content)
            Image.open(image_path).convert("RGB")
            return True
        else:
            print(f"Failed to download {url} (status: {response.status_code})")
            return False
    except Exception as e:
        print(f"Error downloading {url}: {e}")
        return False

successful_images = []
dataset['image_filename'] = dataset['Image_name'].apply(lambda x: f"{x}.jpg")

for i, row in dataset.iterrows():
    filename = row['image_filename']
    original_path = os.path.join(image_folder_path, filename)
    new_path = os.path.join(new_image_folder, filename)
    
    if os.path.exists(original_path):
        try:
            Image.open(original_path).convert("RGB")
            os.system(f"cp {original_path} {new_path}")
            successful_images.append(filename)
        except Exception as e:
            print(f"Error copying {filename}: {e}")
            url = row['url']
            if download_image(url, filename, new_image_folder):
                successful_images.append(filename)
    else:
        print(f"Image {filename} not found, downloading...")
        url = row['url']
        if download_image(url, filename, new_image_folder):
            successful_images.append(filename)

print(f"Successfully processed {len(successful_images)} images")
dataset = dataset[dataset['image_filename'].isin(successful_images)].reset_index(drop=True)
print(f"Final dataset size after filtering: {len(dataset)} rows")
# Out:
# Successfully processed 2000 images
# Final dataset size after filtering: 2000 rows

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import torch
from collections import Counter
import nltk
nltk.download('punkt')

image_transform = transforms.Compose([
    transforms.Resize((224, 224)),  # EfficientNet-B0 default size
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def clean_text(text):
    return text.lower().strip()

dataset['Paragraph'] = dataset['Paragraph'].apply(clean_text)

all_captions = dataset['Paragraph'].tolist()
tokenizer = nltk.word_tokenize
word_counts = Counter()
for caption in all_captions:
    word_counts.update(tokenizer(caption))

vocab = ['<PAD>', '<START>', '<END>', '<UNK>'] + [word for word, count in word_counts.items() if count >= 3]
word2idx = {word: idx for idx, word in enumerate(vocab)}
idx2word = {idx: word for word, idx in word2idx.items()}
vocab_size = len(vocab)
print(f"Vocabulary size: {vocab_size}")

def caption_to_sequence(caption):
    tokens = tokenizer(caption)
    seq = [word2idx.get(token, word2idx['<UNK>']) for token in tokens]
    return [word2idx['<START>']] + seq + [word2idx['<END>']]

class ImageCaptionDataset(Dataset):
    def __init__(self, dataframe, image_folder, transform=None):
        self.dataframe = dataframe
        self.image_folder = image_folder
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        image_path = os.path.join(self.image_folder, row['image_filename'])
        try:
            image = Image.open(image_path).convert("RGB")
            caption = row['Paragraph']
            if self.transform:
                image = self.transform(image)
            caption_seq = caption_to_sequence(caption)
            return image, torch.tensor(caption_seq)
        except Exception as e:
            print(f"Error loading {image_path}: {e}")
            return None, None

train_data = dataset[dataset['train'] == 1]
val_data = dataset[dataset['val'] == 1]
test_data = dataset[dataset['test'] == 1]

batch_size = 8
train_dataset = ImageCaptionDataset(train_data, new_image_folder, image_transform)
val_dataset = ImageCaptionDataset(val_data, new_image_folder, image_transform)
test_dataset = ImageCaptionDataset(test_data, new_image_folder, image_transform)

def collate_fn(batch):
    batch = [b for b in batch if b[0] is not None]
    if len(batch) == 0:
        return None
    images, captions = zip(*batch)
    images = torch.stack(images)
    captions = torch.nn.utils.rnn.pad_sequence(captions, batch_first=True, padding_value=word2idx['<PAD>'])
    return images, captions

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Vocabulary size: 2077

# %%
import torch.nn as nn
from torchvision.models import efficientnet_b0

class CNNLSTMModel(nn.Module):
    def __init__(self, vocab_size, embed_size=256, hidden_size=512, num_layers=1):
        super(CNNLSTMModel, self).__init__()
        self.cnn = efficientnet_b0(pretrained=True)
        self.cnn.classifier = nn.Identity()  # Remove final classifier layer
        # Freeze CNN initially
        for param in self.cnn.parameters():
            param.requires_grad = False
        self.embed = nn.Embedding(vocab_size, embed_size)
        # EfficientNet-B0 outputs 1280 features
        self.lstm = nn.LSTM(embed_size + 1280, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, vocab_size)
        
    def forward(self, images, captions):
        features = self.cnn(images)  # [batch_size, 1280]
        features = features.unsqueeze(1).repeat(1, captions.size(1), 1)  # [batch_size, seq_len, 1280]
        embeddings = self.embed(captions)  # [batch_size, seq_len, embed_size]
        inputs = torch.cat((features, embeddings), dim=2)  # [batch_size, seq_len, 1280 + embed_size]
        outputs, _ = self.lstm(inputs)  # [batch_size, seq_len, hidden_size]
        outputs = self.fc(outputs)  # [batch_size, seq_len, vocab_size]
        return outputs

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNNLSTMModel(vocab_size).to(device)
print("Model loaded on:", device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 111MB/s]
# Model loaded on: cpu

# %%
from tqdm import tqdm
from torch.optim.lr_scheduler import StepLR

criterion = nn.CrossEntropyLoss(ignore_index=word2idx['<PAD>'])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=1, gamma=0.9)

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

num_epochs = 10
output_dir = '/kaggle/working/checkpoints'
os.makedirs(output_dir, exist_ok=True)

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    train_correct = 0
    train_total = 0
    for batch in tqdm(train_loader, desc=f"Epoch {epoch+1} - Training"):
        if batch is None:
            continue
        images, captions = batch
        images, captions = images.to(device), captions.to(device)
        
        outputs = model(images, captions[:, :-1])
        loss = criterion(outputs.reshape(-1, vocab_size), captions[:, 1:].reshape(-1))
        train_loss += loss.item()
        
        preds = outputs.argmax(dim=2)
        mask = captions[:, 1:] != word2idx['<PAD>']
        train_correct += (preds[mask] == captions[:, 1:][mask]).sum().item()
        train_total += mask.sum().item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        torch.cuda.empty_cache()

    avg_train_loss = train_loss / len(train_loader)
    train_accuracy = train_correct / train_total if train_total > 0 else 0
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    print(f"Epoch {epoch+1}, Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")

    torch.save(model.state_dict(), os.path.join(output_dir, f'model_epoch_{epoch+1}.pt'))

    model.eval()
    val_loss = 0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for batch in tqdm(val_loader, desc=f"Epoch {epoch+1} - Validation"):
            if batch is None:
                continue
            images, captions = batch
            images, captions = images.to(device), captions.to(device)
            outputs = model(images, captions[:, :-1])
            loss = criterion(outputs.reshape(-1, vocab_size), captions[:, 1:].reshape(-1))
            val_loss += loss.item()
            
            preds = outputs.argmax(dim=2)
            mask = captions[:, 1:] != word2idx['<PAD>']
            val_correct += (preds[mask] == captions[:, 1:][mask]).sum().item()
            val_total += mask.sum().item()

    avg_val_loss = val_loss / len(val_loader)
    val_accuracy = val_correct / val_total if val_total > 0 else 0
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
    print(f"Epoch {epoch+1}, Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")

    scheduler.step()
    if epoch > 1 and val_losses[-1] > val_losses[-2]:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1 - Training: 100%|██████████| 192/192 [02:05<00:00,  1.53it/s]
# Epoch 1, Train Loss: 4.4070, Train Accuracy: 0.2480
# Epoch 1 - Validation: 100%|██████████| 31/31 [00:12<00:00,  2.49it/s]
# Epoch 1, Val Loss: 3.9004, Val Accuracy: 0.2963
# Epoch 2 - Training: 100%|██████████| 192/192 [02:09<00:00,  1.49it/s]
# Epoch 2, Train Loss: 3.6526, Train Accuracy: 0.3153
# Epoch 2 - Validation: 100%|██████████| 31/31 [00:12<00:00,  2.45it/s]
# Epoch 2, Val Loss: 3.5943, Val Accuracy: 0.3250
# Epoch 3 - Training: 100%|██████████| 192/192 [02:08<00:00,  1.50it/s]
# Epoch 3, Train Loss: 3.3387, Train Accuracy: 0.3426
# Epoch 3 - Validation: 100%|██████████| 31/31 [00:12<00:00,  2.53it/s]
# Epoch 3, Val Loss: 3.4439, Val Accuracy: 0.3420
# Epoch 4 - Training: 100%|██████████| 192/192 [02:07<00:00,  1.50it/s]
# Epoch 4, Train Loss: 3.1238, Train Accuracy: 0.3629
# Epoch 4 - Validation: 100%|██████████| 31/31 [00:12<00:00,  2.55it/s]
# Epoch 4, Val Loss: 3.3663, Val Accuracy: 0.3482
# Epoch 5 - Training: 100%|██████████| 192/192 [02:07<00:00,  1.51it/s]
# Epoch 5, Train Loss: 2.9563, Train Accuracy: 0.3792
# Epoch 5 - Validation: 100%|██████████| 31/31 [00:13<00:00,  2.36it/s]
# Epoch 5, Val Loss: 3.2742, Val Accuracy: 0.3581
# Epoch 6 - Training: 100%|██████████| 192/192 [02:11<00:00,  1.46it/s]
# Epoch 6, Train Loss: 2.8204, Train Accuracy: 0.3920
# Epoch 6 - Validation: 100%|██████████| 31/31 [00:12<00:00,  2.40it/s]
# Epoch 6, Val Loss: 3.2601, Val Accuracy: 0.3587
# Epoch 7 - Training: 100%|██████████| 192/192 [02:07<00:00,  1.51it/s]
# Epoch 7, Train Loss: 2.7130, Train Accuracy: 0.4048
# Epoch 7 - Validation: 100%|██████████| 31/31 [00:12<00:00,  2.58it/s]
# Epoch 7, Val Loss: 3.2299, Val Accuracy: 0.3652
# Epoch 8 - Training: 100%|██████████| 192/192 [02:07<00:00,  1.50it/s]
# Epoch 8, Train Loss: 2.6142, Train Accuracy: 0.4159
# Epoch 8 - Validation: 100%|██████████| 31/31 [00:12<00:00,  2.41it/s]
# Epoch 8, Val Loss: 3.2116, Val Accuracy: 0.3656
# Epoch 9 - Training: 100%|██████████| 192/192 [02:06<00:00,  1.52it/s]
# Epoch 9, Train Loss: 2.5290, Train Accuracy: 0.4274
# Epoch 9 - Validation: 100%|██████████| 31/31 [00:12<00:00,  2.52it/s]
# Epoch 9, Val Loss: 3.1777, Val Accuracy: 0.3678
# Epoch 10 - Training: 100%|██████████| 192/192 [02:07<00:00,  1.51it/s]
# Epoch 10, Train Loss: 2.4573, Train Accuracy: 0.4363
# Epoch 10 - Validation: 100%|██████████| 31/31 [00:11<00:00,  2.59it/s]
# Epoch 10, Val Loss: 3.2187, Val Accuracy: 0.3659
# Early stopping triggered

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, label='Train Accuracy')
plt.plot(range(1, len(val_accuracies) + 1), val_accuracies, label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig('/kaggle/working/loss_accuracy_curves.png')
plt.show()
print("Curves saved to /kaggle/working/loss_accuracy_curves.png")
# Out:
# Curves saved to /kaggle/working/loss_accuracy_curves.png
